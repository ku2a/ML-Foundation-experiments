# %% [markdown]
# # Clasificación por KNN
#
# Cargamos los paquetes

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import shap

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Cargamos los datos, definimos el grid de hiperparámetros y hacemos la búsqueda en cuadrícula

# %%
df = pd.read_csv("../data/match_data_no_gold.csv")
X = df.drop("blueTeamWin", axis=1)
y = df["blueTeamWin"]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)
X_test, X_val, y_test, y_val = train_test_split(X_val, y_val, test_size=0.5, random_state=42, stratify=y_val)

pipeline = Pipeline([
    ('scaler', RobustScaler()),
    ('knn', KNeighborsClassifier())
])

# %%
X_train.shape
# Out:
# (14530, 15)

# %%
from math import sqrt
k = int(sqrt(X_train.shape[0]))
k
# Out:
# 120

# %%
param_grid = {
    "knn__n_neighbors": list(range(k-21, k+11, 2)),
    "knn__weights": ['uniform', 'distance'],
    "knn__metric": ['euclidean', 'manhattan']
}

grid_search = GridSearchCV(pipeline, param_grid, cv=5, n_jobs=-1, scoring='roc_auc')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', RobustScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'knn__metric': ['euclidean', 'manhattan'],
#                          'knn__n_neighbors': [99, 101, 103, 105, 107, 109, 111,
#                                               113, 115, 117, 119, 121, 123, 125,
#                                               127, 129],
#                          'knn__weights': ['uniform', 'distance']},
#              scoring='roc_auc')

# %%
best_model = grid_search.best_estimator_
print(f"Mejores hiperparámetros: {grid_search.best_params_}")
print(f"Mejor ROC en CV: {grid_search.best_score_:.4f}")

y_pred = best_model.predict(X_val)
print("Matriz de Confusión:")
print(confusion_matrix(y_val, y_pred))
print("\nReporte de Clasificación:")
print(classification_report(y_val, y_pred, target_names=["Red Team Win", "Blue Team Win"]))
# Out:
# Mejores hiperparámetros: {'knn__metric': 'manhattan', 'knn__n_neighbors': 121, 'knn__weights': 'distance'}
# Mejor ROC en CV: 0.8296
# Matriz de Confusión:
# [[1912  537]
#  [ 603 1792]]
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#  Red Team Win       0.76      0.78      0.77      2449
# Blue Team Win       0.77      0.75      0.76      2395
#
#      accuracy                           0.76      4844
#     macro avg       0.76      0.76      0.76      4844
#  weighted avg       0.76      0.76      0.76      4844

# %% [markdown]
# Visualización

# %%
results = pd.DataFrame(grid_search.cv_results_)
best_weight = grid_search.best_params_['knn__weights']
best_distance = grid_search.best_params_['knn__metric']
results = results[(results['param_knn__weights'] == best_weight) & (results['param_knn__metric'] == best_distance)]

plt.figure(figsize=(10, 6))
plt.plot(results['param_knn__n_neighbors'], results['mean_test_score'], marker='o', color='r')
plt.title(f'Rendimiento vs Número de Vecinos (weights={best_weight}, metric={best_distance})')
plt.xlabel('Número de Vecinos (k)')
plt.ylabel('Accuracy Promedio en CV')
plt.xticks(results['param_knn__n_neighbors'])
plt.grid()
plt.show()

# %% [markdown]
# Interpretabilidad con SHAP

# %%
def predict_proba_wrapper(data):
    if isinstance(data, np.ndarray):
        data = pd.DataFrame(data, columns=X_train.columns)
    return best_model.predict_proba(data)


# Seleccionamos una muestra del conjunto de test para acelerar el cálculo de SHAP
sample_data = shap.sample(X_val, 50, random_state=0)

# Obtenemos el explainer SHAP
explainer = shap.KernelExplainer(predict_proba_wrapper, sample_data)

# Calculamos los valores SHAP para el conjunto de test
instance = X_val.iloc[[0]]
shap_values = explainer.shap_values(instance)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 15
#      13 # Calculamos los valores SHAP para el conjunto de test
#      14 instance = X_val.iloc[[1]]
# ---> 15 shap_values = explainer.shap_values(instance)
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/shap/explainers/_kernel.py:275, in KernelExplainer.shap_values(self, X, **kwargs)
#     273 if self.keep_index:
#     274     data = convert_to_instance_with_index(data, column_name, index_value[i : i + 1], index_name)
# --> 275 explanations.append(self.explain(data, **kwargs))
#     276 if kwargs.get("gc_collect", False):
#     277     gc.collect()
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/shap/explainers/_kernel.py:479, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     476     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     478 # execute the model on the synthetic samples we have created
# --> 479 self.run()
#     481 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     482 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/shap/explainers/_kernel.py:624, in KernelExplainer.run(self)
#     622     if self.keep_index_ordered:
#     623         data = data.sort_index()
# --> 624 modelOut = self.model.f(data)
#     625 if isinstance(modelOut, (pd.DataFrame, pd.Series)):
#     626     modelOut = modelOut.values
#
# Cell In[11], line 4, in predict_proba_wrapper(data)
#       2 if isinstance(data, np.ndarray):
#       3     data = pd.DataFrame(data, columns=X_train.columns)
# ----> 4 return best_model.predict_proba(data)
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/sklearn/pipeline.py:905, in Pipeline.predict_proba(self, X, **params)
#     903     for _, name, transform in self._iter(with_final=False):
#     904         Xt = transform.transform(Xt)
# --> 905     return self.steps[-1][1].predict_proba(Xt, **params)
#     907 # metadata routing enabled
#     908 routed_params = process_routing(self, "predict_proba", **params)
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/sklearn/neighbors/_classification.py:374, in KNeighborsClassifier.predict_proba(self, X)
#     372     neigh_dist = None
#     373 else:
# --> 374     neigh_dist, neigh_ind = self.kneighbors(X)
#     376 classes_ = self.classes_
#     377 _y = self._y
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/sklearn/neighbors/_base.py:923, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     918     if issparse(X):
#     919         raise ValueError(
#     920             "%s does not work with sparse matrices. Densify the data, "
#     921             "or set algorithm='brute'" % self._fit_method
#     922         )
# --> 923     chunked_results = Parallel(n_jobs, prefer="threads")(
#     924         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     925         for s in gen_even_slices(X.shape[0], n_jobs)
#     926     )
#     927 else:
#     928     raise ValueError("internal: _fit_method not recognized")
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/OneDrive/linux/UPM/year3/sem1/AA/practica02_git/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# Visualizamos los valores SHAP
shap.initjs()
shap.force_plot(
    explainer.expected_value[0],
    shap_values[0][:, 0],
    instance.iloc[0],
    matplotlib=True,
    text_rotation=45,
    link="logit"
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %%
shap_values_summary = explainer.shap_values(sample_data)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.figure(dpi=100)
shap.summary_plot(
    shap_values_summary[:, :, 1],
    sample_data,
    plot_type="dot",
    max_display=10,
    show=False
)
plt.title("Resumen de valores SHAP para la clase positiva (blueTeamWin=1)")
plt.show()
